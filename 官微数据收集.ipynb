# %%
! git clone https://github.com/dataabc/weibo-crawler.git
# Out:
# Cloning into 'weibo-crawler'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 650 (delta 50), reused 66 (delta 37), pack-reused 544
# Receiving objects: 100% (650/650), 296.23 KiB | 7.79 MiB/s, done.
# Resolving deltas: 100% (329/329), done.

# %%
# !pip3 freeze > requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/weibo-crawler/weibo.py
# Out:
# 准备搜集 乘风2023官方微博 的微博
# Progress:   0%|          | 0/559 [00:00<?, ?it/s]
# 已获取用户 乘风2023官方微博 的微博，内容为 【#乘风之夜#正片上线】
# 决战之夜，三支联创队展开最终角逐，11个年度乘风席位究竟花落谁家？锁定#乘风2023#一起揭晓！
# 乘风2023 乘风之夜：11个年度乘风席位揭晓 Ella获乘风年度总冠军
#
# 已获取用户 乘风2023官方微博 的微博，内容为 一个令人惊艳的舞台表演，除了歌手的演绎，舞美设计亦十分重要。开播以来，《#乘风2023#》 备受大众关注，艺术总监唐焱表示，本季的舞台设计中其实是在表达一种东方的审美：化繁为简，大量留白。”
# 乘风2023官方微博的微博视频
#
# 已获取用户 乘风2023官方微博 的微博，内容为 一起乘风，奔赴热爱。#88VIP牵手芒果TV##88VIP芒果会员免费领。
# 已获取用户 乘风2023官方微博 的微博，内容为 #乘风后续# 长大后的芭比女孩，都成了乘风破浪的姐姐。今晚来看秀吗？想要的多'芭'胺穿搭、秋冬一线战袍，都在这儿。
# 已获取用户 乘风2023官方微博 的微博，内容为 湖南卫视、芒果TV与《乘风2023》携手人民日报新媒体为您献上一场沁人心脾的“夏日音乐会”。在大暑节气，愿你邂逅一缕清风、收获一份清凉！《乘风2023》嘉宾@孙悦、黄丽玲@天生歌姬A-Lin 、@卢靖姗CelinaJade 、@许靖韵Angela 、@唐伯虎Annie 、@汪小敏 、@陈冰KiKi 和@李莎旻子Leo 即将乘风而来，更有 ...
# 全文
# 已获取用户 乘风2023官方微博 的微博，内容为 #来听一场夏日音乐会# @湖南卫视 @芒果TV #乘风2023# 携手@人民日报 今晚8:00  为您献上一场沁人心脾的“夏日音乐会”。在大暑节气，愿你邂逅一缕清风、收获一份清凉！
# 乘风嘉宾@孙悦、黄丽玲@天生歌姬A-Lin 、@卢靖姗CelinaJade 、@许靖韵Angela 、@唐伯虎Annie 、@汪小敏 、@陈冰KiKi 和@李莎旻子Leo ...
# 全文
# ...

# %%
import pandas as pd
# Out:
# NumExpr defaulting to 2 threads.

# %%
df = pd.read_csv('/content/weibo-crawler/weibo/乘风2023官方微博/7397600914.csv')

# %%
df
# Out:
#                          id  \
# 4926023386275658  NaUZcqkAi
# 4933263656754132  NdXl3sl3C
# 4930719518821776  NcT9BB0WI
# 4927857409131806  NbGHiCjBc
# 4926760456555953  Nbea1rvvb
# ...                     ...
# 4897995055958372  MF7ixp02M
# 4897977757337069  MF6QDuMHP
# 4897977255330854  MF6PPmmNw
# 4897976750967787  MF6P143Lt
# 4897976256562132  MF6Odrx6Q
#
#                                                                 bid  正文  \
# 4926023386275658  【#乘风之夜#正片上线】\n决战之夜，三支联创队展开最终角逐，11个年度乘风席位究竟花落谁家... NaN
# 4933263656754132  一个令人惊艳的舞台表演，除了歌手的演绎，舞美设计亦十分重要。开播以来，《#乘风2023#》 ... NaN
# 4930719518821776             一起乘风，奔赴热爱。#88VIP牵手芒果TV##88VIP芒果会员免费领。  NaN
# 4927857409131806  #乘风后续# 长大后的芭比女孩，都成了乘风破浪的姐姐。今晚来看秀吗？想要的多'芭'胺穿搭、秋... NaN
# 4926760456555953  湖南卫视、芒果TV与《乘风2023》携手人民日报新媒体为您献上一场沁人心脾的“夏日音乐会”。... NaN
# ...                                                             ...  ..
# 4897995055958372  #乘风2023初舞台节目单#预告\n大幕拉开，每一首歌背后皆是故事\n灯光亮起，在更大的舞台... NaN
# ...

# %%
df.to_csv('/content/drive/My Drive/weibo/浪姐官方微博.csv')

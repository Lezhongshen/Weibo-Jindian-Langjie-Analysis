# %%
! git clone https://github.com/dataabc/weibo-search.git
# Out:
# Cloning into 'weibo-search'...
# remote: Enumerating objects: 505, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 505 (delta 164), reused 170 (delta 159), pack-reused 311
# Receiving objects: 100% (505/505), 82.13 KiB | 7.47 MiB/s, done.
# Resolving deltas: 100% (291/291), done.

# %%
pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 82.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 13.2 MB/s eta 0:00:00
# ...

# %%
# !pip3 freeze > requirements.txt

# %%
#!pip install django
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 42.6 MB/s eta 0:00:00
# ...

# %%
#import os
#from django.conf import settings

# Check if Django settings are already configured
#if not settings.configured:
    # Set Django settings
#    os.environ.setdefault("DJANGO_SETTINGS_MODULE", "/content/weibo-search/weibo/settings.py")
#    settings.configure(DEBUG=True, SOME_SETTING='some value')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/weibo-search
# Out:
# /content/weibo-search

# %%
# !scrapy crawl search #-s JOBDIR=crawls/search
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#           'https://wx4.sinaimg.cn/large/769058aagy1hdoyoggq98j21yc0wi7wh.jpg'],
#  'reposts_count': '0',
#  'retweet_id': '',
#  'screen_name': '啦啦爱吃芋泥',
#  'source': 'iPhone客户端',
#  'text': '开始看乘风破浪的姐姐啦，好像今年的名字就叫乘风，舞美真好看啊～',
#  'topics': '',
#  'user_id': '1989171370',
#  'video_url': ''}
# {'article_url': '',
#  'at_users': '',
#  'attitudes_count': '0',
#  'bid': 'MFkzntrey',
#  'comments_count': '2',
#  'created_at': '2023-05-06 21:01',
#  'id': '4898505217016202',
#  'ip': '浙江',
#  'location': '',
#  'pics': '',
#  'reposts_count': '0',
#  'retweet_id': '',
#  'screen_name': '醋溜小肥杨',
#  'source': 'iPhone客户端',
#  'text': '#乘风破浪的姐姐#倒回去看了三遍极乐净土，太可爱了，小小的身躯大大的力量',
#  'topics': '乘风破浪的姐姐',
#  'user_id': '3189233604',
#  'video_url': ''}
# {'article_url': '',
#  'at_users': '',
#  'attitudes_count': '3',
#  'bid': 'MFkzeycw2',
#  'comments_count': '0',
#  'created_at': '2023-05-06 21:01',
#  'id': '4898505128151266',
#  'ip': '山东',
#  'location': '',
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/weibo-search/结果文件/乘风破浪的姐姐/乘风破浪的姐姐.csv')

# %%
df
# Out:
#                     id        bid     user_id        用户昵称  \
# 0     4900721452911451  N0iLDcdoT  5135796084       不行报井吧
# 1     4900721151185497  N0iL94YoV  5825861665   mini_小美女版
# 2     4900720786016038  N0iKypf2S  1919155483     神奇八卦在哪里
# 3     4900720031302050  N0iJl5sIO  2550756250  FashionBro
# 4     4900719939818549  N0iJbFcfH  2186079711    Sidney曹旭
# ...                ...        ...         ...         ...
# 1169  4898179798007942  MFc6vxBem  6539165753     小二今天不洗碗
# 1170  4898179789358046  MFc6uDgse  6617415833        剧综酸酸
# 1171  4898179784644748  MFc6ujuji  7136238618      Aqr499
# 1172  4898179621067274  MFc6e4tE6  5621787454       一只麦当楠
# 1173  4898179411613412  MFc5T6LIM  7383174270        -柑悄-
#
#                                                    微博正文  头条文章url 发布位置  \
# 0         #乘风破浪下一季叫什么#他怎么不把披荆斩棘的哥哥给改了呢就行哥哥披荆斩棘不行姐姐乘风破浪吗      NaN  NaN
# 1                              乘风破浪的姐姐那个越南芝芙chipu姐姐的确漂亮      NaN  NaN
# ...

# %%
df.to_csv('/content/drive/My Drive/weibo/浪姐2.csv')
